# %%
import pandas as pd

# %%
PATH=r'C:\Users\tensorflow\Desktop\iloraz_inteligencji\kaggle\Kaggle-Rossman'

# %%
table_names = ['train', 'test', 'store','store_states', 'state_names','weather','googletrend']

# %%
tables = [pd.read_csv(f'{PATH}\\{fname}.csv', low_memory=False) for fname in table_names]

# %%
from IPython.display import HTML, display

# %%
train, test, store, store_states, state_names, googletrend, weather = tables

# %%
train.StateHoliday = train.StateHoliday!='0'
test.StateHoliday = test.StateHoliday!='0'

# %%
def join_df(left, right, left_on, right_on=None, suffix='_y'):
    if right_on is None: right_on = left_on
    return left.merge(right, how='left', left_on=left_on, right_on=right_on, 
                      suffixes=("", suffix))

# %%
weather = join_df(weather, state_names, "file", "StateName")

# %%
googletrend
# Out:
#                      file        Date  Max_TemperatureC  Mean_TemperatureC  \
# 0      NordrheinWestfalen  2013-01-01                 8                  4
# 1      NordrheinWestfalen  2013-01-02                 7                  4
# 2      NordrheinWestfalen  2013-01-03                11                  8
# 3      NordrheinWestfalen  2013-01-04                 9                  9
# 4      NordrheinWestfalen  2013-01-05                 8                  8
# 5      NordrheinWestfalen  2013-01-06                 9                  8
# 6      NordrheinWestfalen  2013-01-07                 9                  8
# 7      NordrheinWestfalen  2013-01-08                 8                  7
# 8      NordrheinWestfalen  2013-01-09                 6                  6
# 9      NordrheinWestfalen  2013-01-10                 6                  4
# 10     NordrheinWestfalen  2013-01-11                 2                 -1
# 11     NordrheinWestfalen  2013-01-12                 2                 -2
# 12     NordrheinWestfalen  2013-01-13                 1                 -3
# 13     NordrheinWestfalen  2013-01-14                -2                 -3
# 14     NordrheinWestfalen  2013-01-15                -1                 -4
# 15     NordrheinWestfalen  2013-01-16                -3                 -3
# 16     NordrheinWestfalen  2013-01-17                -2                 -3
# 17     NordrheinWestfalen  2013-01-18                 0                 -2
# 18     NordrheinWestfalen  2013-01-19                -3                 -4
# 19     NordrheinWestfalen  2013-01-20                 0                 -3
# 20     NordrheinWestfalen  2013-01-21                 0                 -1
# 21     NordrheinWestfalen  2013-01-22                 1                 -1
# 22     NordrheinWestfalen  2013-01-23                -1                 -2
# 23     NordrheinWestfalen  2013-01-24                -2                 -4
# 24     NordrheinWestfalen  2013-01-25                -2                 -2
# 25     NordrheinWestfalen  2013-01-26                 0                 -2
# 26     NordrheinWestfalen  2013-01-27                 4                  2
# 27     NordrheinWestfalen  2013-01-28                 6                  3
# 28     NordrheinWestfalen  2013-01-29                12                  8
# 29     NordrheinWestfalen  2013-01-30                13                 11
# ...                   ...         ...               ...                ...
# 15810            Saarland  2015-08-19                22                 14
# 15811            Saarland  2015-08-20                25                 18
# 15812            Saarland  2015-08-21                26                 19
# 15813            Saarland  2015-08-22                26                 19
# 15814            Saarland  2015-08-23                27                 20
# 15815            Saarland  2015-08-24                19                 17
# 15816            Saarland  2015-08-25                21                 17
# 15817            Saarland  2015-08-26                26                 19
# 15818            Saarland  2015-08-27                29                 23
# 15819            Saarland  2015-08-28                19                 18
# 15820            Saarland  2015-08-29                30                 22
# 15821            Saarland  2015-08-30                32                 25
# 15822            Saarland  2015-08-31                31                 25
# 15823            Saarland  2015-09-01                21                 18
# 15824            Saarland  2015-09-02                20                 15
# 15825            Saarland  2015-09-03                20                 15
# 15826            Saarland  2015-09-04                18                 12
# 15827            Saarland  2015-09-05                16                 10
# 15828            Saarland  2015-09-06                16                 11
# 15829            Saarland  2015-09-07                16                 10
# 15830            Saarland  2015-09-08                19                 14
# 15831            Saarland  2015-09-09                20                 14
# 15832            Saarland  2015-09-10                20                 14
# 15833            Saarland  2015-09-11                21                 14
# 15834            Saarland  2015-09-12                23                 17
# 15835            Saarland  2015-09-13                21                 17
# 15836            Saarland  2015-09-14                18                 14
# 15837            Saarland  2015-09-15                16                 12
# 15838            Saarland  2015-09-16                19                 15
# 15839            Saarland  2015-09-17                14                 13
#
#        Min_TemperatureC  Dew_PointC  MeanDew_PointC  Min_DewpointC  \
# 0                     2           7               5              1
# 1                     1           5               3              2
# 2                     6          10               8              4
# 3                     8           9               9              8
# 4                     7           8               7              6
# 5                     7           8               7              6
# 6                     7           8               7              5
# 7                     5           6               5              4
# 8                     5           6               4              3
# 9                     3           4               3              1
# 10                   -3           2              -3             -5
# 11                   -7          -3              -6             -8
# 12                   -6          -3              -6             -8
# 13                   -5          -2              -5             -8
# 14                   -7          -2              -4             -7
# 15                   -4          -3              -4             -5
# 16                   -4          -3              -4             -6
# 17                   -5          -3              -4             -7
# 18                   -5          -5              -7             -9
# 19                   -7          -2              -6             -9
# 20                   -2          -1              -2             -3
# 21                   -3          -2              -3             -4
# 22                   -3          -3              -4             -6
# 23                   -6          -4              -6             -8
# 24                   -3          -3              -4             -6
# 25                   -4          -1              -4             -6
# 26                   -1           3               1             -2
# 27                    0           3               2             -1
# 28                    3          10               8              3
# 29                    9          11               8              4
# ...                 ...         ...             ...            ...
# 15810                 8          12               8              6
# 15811                11          13               9              5
# 15812                12          12              10              7
# 15813                13          12               8              5
# 15814                13          17              11              6
# 15815                15          17              14              9
# 15816                12          10               8              5
# 15817                12          13               9              7
# 15818                18          17              13             10
# 15819                16          18              17             15
# 15820                15          20              17             15
# 15821                18          19              16             12
# 15822                19          14              12              9
# 15823                14          18              15             12
# 15824                10          13              11              7
# 15825                10          13               9              5
# 15826                 7           9               7              5
# 15827                 5           9               7              5
# 15828                 7           9               6              4
# 15829                 5          11               8              4
# 15830                 9          11               9              7
# 15831                 9          11               7              5
# 15832                 8           7               4              2
# 15833                 7           8               6              2
# 15834                10          16              11              5
# 15835                12          16              14             12
# 15836                11          15              12              7
# 15837                 9          11               8              7
# 15838                11          16              13             10
# 15839                12          14              12             10
#
#        Max_Humidity  Mean_Humidity       ...        Max_VisibilityKm  \
# 0                94             87       ...                    31.0
# 1                93             85       ...                    31.0
# 2               100             93       ...                    31.0
# 3               100             94       ...                    11.0
# 4               100             94       ...                    10.0
# 5               100             92       ...                    18.0
# 6                98             88       ...                    26.0
# 7               100             87       ...                    18.0
# 8               100             91       ...                    19.0
# 9                96             86       ...                    26.0
# 10              100             85       ...                    31.0
# 11              100             79       ...                    31.0
# 12               86             75       ...                    31.0
# 13               99             85       ...                    18.0
# 14              100             86       ...                    26.0
# 15               99             91       ...                     5.0
# 16               94             88       ...                     7.0
# 17               94             82       ...                    31.0
# 18               80             74       ...                    26.0
# 19               94             84       ...                    19.0
# 20              100             91       ...                     7.0
# 21               94             86       ...                     7.0
# 22               90             80       ...                     7.0
# 23               93             82       ...                    14.0
# 24               95             83       ...                    26.0
# 25              100             81       ...                    26.0
# 26               95             86       ...                    26.0
# 27               93             84       ...                    31.0
# 28               96             88       ...                    31.0
# 29               94             79       ...                    31.0
# ...             ...            ...       ...                     ...
# 15810           100             66       ...                    19.0
# 15811            94             58       ...                    31.0
# 15812            82             57       ...                    31.0
# 15813            72             49       ...                    31.0
# 15814            97             61       ...                    14.0
# 15815            98             83       ...                    31.0
# 15816            77             57       ...                    31.0
# 15817            72             51       ...                    10.0
# 15818            94             55       ...                    26.0
# 15819           100             93       ...                    31.0
# 15820           100             74       ...                    31.0
# 15821            96             58       ...                    31.0
# 15822            60             40       ...                     NaN
# 15823            99             83       ...                    26.0
# 15824           100             79       ...                    31.0
# 15825            94             68       ...                    31.0
# 15826            96             71       ...                    31.0
# 15827           100             76       ...                    31.0
# 15828            97             74       ...                    31.0
# 15829            99             82       ...                    31.0
# 15830            95             72       ...                    31.0
# 15831            93             65       ...                    31.0
# 15832            76             53       ...                    31.0
# 15833            87             58       ...                    31.0
# 15834            94             69       ...                    31.0
# 15835           100             88       ...                    31.0
# 15836            99             85       ...                    31.0
# 15837            93             77       ...                    31.0
# 15838            97             90       ...                    31.0
# 15839            99             92       ...                    31.0
#
#        Mean_VisibilityKm  Min_VisibilitykM  Max_Wind_SpeedKm_h  \
# 0                   12.0               4.0                  39
# 1                   14.0              10.0                  24
# 2                    8.0               2.0                  26
# 3                    5.0               2.0                  23
# 4                    6.0               3.0                  16
# 5                    7.0               5.0                  16
# 6                    8.0               2.0                  16
# 7                    9.0               3.0                  21
# 8                    8.0               2.0                  21
# 9                   12.0               6.0                  16
# 10                  12.0               9.0                  21
# 11                  17.0              10.0                  16
# 12                  13.0              10.0                  21
# 13                   8.0               2.0                  23
# 14                   7.0               1.0                  27
# 15                   3.0               2.0                  14
# 16                   4.0               3.0                  16
# 17                  11.0               8.0                  21
# 18                  13.0              10.0                  26
# 19                   8.0               1.0                  24
# 20                   5.0               2.0                  16
# 21                   6.0               5.0                  11
# 22                   5.0               5.0                  14
# 23                  10.0               6.0                  21
# 24                   9.0               1.0                  23
# 25                  11.0               3.0                  34
# 26                  12.0               5.0                  35
# 27                  15.0              10.0                  32
# 28                  12.0               6.0                  45
# 29                  12.0               5.0                  47
# ...                  ...               ...                 ...
# 15810               10.0               3.0                  14
# 15811               24.0              10.0                  10
# 15812               31.0              31.0                  14
# 15813               31.0              31.0                  21
# 15814               10.0               4.0                  37
# 15815               12.0               3.0                  32
# 15816               11.0              10.0                  40
# 15817               10.0              10.0                  21
# 15818               11.0              10.0                  29
# 15819                8.0               2.0                  18
# 15820                8.0               0.0                  13
# 15821               28.0              26.0                  19
# 15822                NaN               NaN                  34
# 15823               11.0               1.0                  34
# 15824                5.0               0.0                  14
# 15825               16.0              10.0                  23
# 15826               12.0              10.0                  26
# 15827               12.0               6.0                  24
# 15828               13.0              10.0                  19
# 15829               14.0               7.0                  14
# 15830               14.0               8.0                  18
# 15831               18.0              10.0                  23
# 15832               24.0              10.0                  26
# 15833               20.0              10.0                  21
# 15834               13.0              10.0                  21
# 15835               15.0              10.0                  27
# 15836               13.0               4.0                  32
# 15837               12.0              10.0                  34
# 15838               10.0               4.0                  32
# 15839               14.0               8.0                  27
#
#        Mean_Wind_SpeedKm_h  Max_Gust_SpeedKm_h  Precipitationmm  CloudCover  \
# 0                       26                58.0             5.08         6.0
# 1                       16                 NaN             0.00         6.0
# 2                       21                 NaN             1.02         7.0
# 3                       14                 NaN             0.25         7.0
# 4                       10                 NaN             0.00         7.0
# 5                       11                 NaN             0.00         7.0
# 6                       10                 NaN             0.00         7.0
# 7                       13                 NaN             0.00         7.0
# 8                       14                 NaN             4.06         8.0
# 9                       11                 NaN             0.00         6.0
# 10                       8                 NaN             0.00         4.0
# 11                       6                 NaN             0.00         2.0
# 12                      11                 NaN             0.00         4.0
# 13                       8                 NaN             0.00         6.0
# 14                      18                 NaN             0.76         7.0
# 15                      11                 NaN             0.25         7.0
# 16                      10                 NaN             0.00         7.0
# 17                      11                 NaN             0.00         6.0
# 18                      18                 NaN             0.00         7.0
# 19                      19                 NaN             2.03         7.0
# 20                      11                 NaN             0.00         7.0
# 21                       6                 NaN             0.00         7.0
# 22                       8                 NaN             0.00         6.0
# 23                      13                 NaN             0.00         6.0
# 24                       8                40.0             0.00         7.0
# 25                      24                48.0             0.00         7.0
# 26                      21                53.0             3.05         7.0
# 27                      18                 NaN             0.25         6.0
# 28                      31                61.0             6.10         7.0
# 29                      32                60.0             3.05         5.0
# ...                    ...                 ...              ...         ...
# 15810                    5                 NaN             0.00         3.0
# 15811                    5                 NaN             0.00         1.0
# 15812                   10                 NaN             0.00         NaN
# 15813                   13                 NaN             0.00         NaN
# 15814                   14                55.0             7.11         6.0
# 15815                   13                48.0             7.11         6.0
# 15816                   27                64.0             0.00         5.0
# 15817                   13                 NaN             0.00         5.0
# 15818                   14                39.0             0.00         7.0
# 15819                   11                 NaN             5.08         7.0
# 15820                    8                 NaN             0.00         5.0
# 15821                   10                 NaN             0.00         NaN
# 15822                   13                50.0             0.00         NaN
# 15823                    8                 NaN             5.08         5.0
# 15824                    5                 NaN             0.00         5.0
# 15825                    8                 NaN             0.00         4.0
# 15826                    8                 NaN             0.00         4.0
# 15827                   10                 NaN             0.25         6.0
# 15828                   13                 NaN             0.00         5.0
# 15829                    6                 NaN             0.25         6.0
# 15830                    8                 NaN             0.00         4.0
# 15831                   16                 NaN             0.00         2.0
# 15832                   18                42.0             0.00         1.0
# 15833                   13                 NaN             0.00         6.0
# 15834                   11                 NaN             1.02         6.0
# 15835                   10                50.0             1.02         7.0
# 15836                   16                53.0             9.91         5.0
# 15837                   14                 NaN             0.00         5.0
# 15838                   14                45.0            20.07         7.0
# 15839                   16                47.0             6.10         6.0
#
#                   Events  WindDirDegrees
# 0                   Rain             215
# 1                   Rain             225
# 2                   Rain             240
# 3                   Rain             263
# 4                   Rain             268
# 5                   Rain             258
# 6                   Rain             238
# 7                   Rain             230
# 8                   Rain             222
# 9                   Rain             256
# 10         Fog-Rain-Snow               1
# 11                   NaN             106
# 12                   NaN              47
# 13                  Snow             273
# 14                  Snow              88
# 15                  Snow             348
# 16             Rain-Snow             353
# 17              Fog-Snow              64
# 18                   NaN              61
# 19             Rain-Snow              55
# 20                  Snow             118
# 21                  Snow              11
# 22                  Snow              17
# 23                   NaN              21
# 24         Fog-Rain-Snow              80
# 25             Rain-Snow             158
# 26             Rain-Snow             174
# 27                  Rain             190
# 28                  Rain             216
# 29     Rain-Thunderstorm             233
# ...                  ...             ...
# 15810                Fog              81
# 15811                NaN              48
# 15812                NaN              72
# 15813                NaN              75
# 15814               Rain             124
# 15815               Rain             177
# 15816               Rain             231
# 15817                NaN             186
# 15818               Rain             224
# 15819               Rain             266
# 15820                Fog              88
# 15821                NaN             183
# 15822                NaN             222
# 15823               Rain             281
# 15824           Fog-Rain             305
# 15825                NaN             272
# 15826                NaN             269
# 15827           Fog-Rain             278
# 15828               Rain             299
# 15829               Rain             291
# 15830                NaN              49
# 15831                NaN              61
# 15832                NaN              62
# 15833                NaN              71
# 15834               Rain             185
# 15835               Rain             113
# 15836  Rain-Thunderstorm             213
# 15837               Rain             193
# 15838  Rain-Thunderstorm             147
# 15839               Rain             202
#
# [15840 rows x 24 columns]

# %%
googletrend['Date'] = googletrend.week.str.split('-', expand=True)[0]
googletrend['State'] = googletrend.file.str.split('_', expand=True)[2]
googletrend.loc[googletrend.State=='NI', "State"] = 'HB,NI'
# Out:
# ------------------------------------------------------------------------
# KeyError                               Traceback (most recent call last)
# ~\Miniconda3\envs\gpu\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# KeyError                               Traceback (most recent call last)
# <ipython-input-44-cb3e3c27b402> in <module>()
#       1 googletrend['Date'] = googletrend.Date.str.split(' - ', expand=True)[0]
# ----> 2 googletrend['State'] = googletrend.file.str.split('_', expand=True)[2]
#       3 googletrend.loc[googletrend.State=='NI', "State"] = 'HB,NI'
#
# ~\Miniconda3\envs\gpu\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Miniconda3\envs\gpu\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Miniconda3\envs\gpu\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Miniconda3\envs\gpu\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Miniconda3\envs\gpu\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
